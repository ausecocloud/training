# %% [markdown]
# # Python Notebook Example for reading CSV
#
# Author: Jonathan Yu, CSIRO
#
# This example takes a URL to a CSV file and reads it into a variable in python for further processing via the `Requests` library. There is also example of previewing the CSV using the `Pandas` library via Dataframe. `Pandas` is useful for processing this kind of information. Lastly, the notebook shows you how to use `matplotlib` to plot the data frame from the CSV into a simple bar chart.

# %%
# specify the URL of the CSV file
url = "https://data.gov.au/dataset/22da2db8-b68f-4853-afb3-964239600d56/resource/b10ea060-2025-4a2d-8171-736de0875e4d/download/2016-soe-atmosphere-average-max-4-hr-average-ozone-concentrations-for-major-cities-1999-2014.csv"

# use Python requests library to read the content to a variable 'csv_content'
import requests
csv_content = None
try:
   r = requests.get(url)
   if(r.status_code != 200):
        raise Exception('')
   csv_content = r.text
except Exception:
    print("ERROR: Not able to access url: " + url)

# %%
#preview the data using pandas
import pandas as pd
import numpy as np
df = pd.read_csv(url)
df
# Out:
#     Year  Melbourne( ppm/4h)  Sydney  (ppm/4h)  Brisbane  (ppm/4h)  \
# 0   1999            0.068000          0.082750            0.095333
# 1   2000            0.057500          0.085075            0.074667
# 2   2001            0.052000          0.116125            0.072667
# 3   2002            0.063000          0.093875            0.085000
# 4   2003            0.092000          0.110875            0.071667
# 5   2004            0.076000          0.097889            0.079667
# 6   2005            0.072000          0.099000            0.065667
# 7   2006            0.109500          0.103375            0.066000
# 8   2007            0.094333          0.084122            0.066333
# 9   2008            0.082000          0.073000            0.061000
# 10  2009            0.095000          0.099000            0.061000
# 11  2010            0.071000          0.082000            0.065000
# 12  2011            0.069000          0.101000            0.069000
# 13  2012            0.073000          0.070000            0.065000
# 14  2013            0.083000          0.090000            0.065000
# 15  2014            0.114000          0.090000            0.061000
#
#     Perth (ppm/4h)  Canberra  (ppm/4h)  NEPM Standard  (ppm/4h)
# 0            0.080               0.063                     0.08
# 1            0.072               0.047                     0.08
# 2            0.079               0.051                     0.08
# 3            0.071               0.058                     0.08
# 4            0.071               0.082                     0.08
# 5            0.079               0.060                     0.08
# 6            0.075               0.062                     0.08
# 7            0.072               0.061                     0.08
# 8            0.079               0.072                     0.08
# 9            0.076               0.061                     0.08
# 10           0.092               0.068                     0.08
# 11           0.075               0.049                     0.08
# 12           0.075               0.054                     0.08
# 13           0.108               0.052                     0.08
# 14           0.079               0.059                     0.08
# 15           0.073               0.060                     0.08

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
my_plot = df.plot(kind='bar')
